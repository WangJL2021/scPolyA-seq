# %%
##aim: get APA matrix
#steps:
#1. get big bed from small bed: done
#2. merge polyA sites within a given distance(24nt): this script
#3. using merged feature as row, cell as column, get APA matrix(next script)

import os
os.chdir("/data/jinwf/wangjl/apa/190705PAS/pdf/")
os.getcwd()
# Out:
# '/data/jinwf/wangjl/apa/190705PAS/pdf'

# %%
# step1: Read to dict, if count>1
#file name
import re,time;
pasTotal="/home/wangjl/data/apa/190705PAS/bed/225.pas_PY.bed"
#chr10	159177	159177	chr10:159177:-	20	-
fr=open(pasTotal,'r')
start=time.time();

i=0;
j=0;
pasDB={} #value is array chr1:+ : [1,2,3] position array. May change later, keep position within cluster
pasDict={} #value is dict(position: counts)  chr1:+ : {1: 21, 3:45, 10:2, } pos and counts, not change
for lineR in fr.readlines():
    i+=1
    if i>1000000:
        #break;
        pass;
    line=lineR.strip();
    arr=re.split('\t',line)
    #print(arr) #['chr10', '101688', '101688', 'chr10:101688:-', '1', '-']
    #filter: by count
    if int(arr[4])<=1:
        continue;
    j+=1;
    k=arr[0]+':'+arr[-1]
    if k not in pasDB:
        pasDB[k]=[]
        pasDict[k]={}
    #
    pasDB[k].append(int(arr[1]));
    pasDict[k][arr[1]]=int( arr[4] )
#
fr.close();
print(len(pasDB), len(pasDict));
#
for k in pasDB.keys():
    print(k, len(pasDB[k]) )
print('==end==',round(time.time()-start,2),'s;')
print('Total PAS number i=', i, '; PAS number who has enough support number j=', j,'; Ratio j/i=', round(j/i*100),'%', sep='') #2732224

# Total PAS number i=2732224; PAS number who has enough support number j=1574173; Ratio j/i=58%
# Out:
# 134 134
# chr10:- 34817
# chr10:+ 36373
# chr11:- 41128
# chr11:+ 45987
# chr11_gl000202_random:+ 1
# chr12:- 36984
# chr12:+ 36526
# chr13:+ 18170
# chr13:- 17426
# chr14:+ 23872
# chr14:- 21923
# chr15:+ 23292
# chr15:- 22967
# chr16:- 24587
# chr16:+ 25844
# chr17_ctg5_hap1:+ 24
# chr17_ctg5_hap1:- 22
# chr17:- 34621
# chr17:+ 32373
# chr17_gl000203_random:- 1
# chr17_gl000204_random:+ 3
# chr17_gl000204_random:- 1
# chr17_gl000205_random:- 7
# chr17_gl000205_random:+ 44
# chr18:+ 16113
# chr18:- 15498
# chr19:- 30609
# chr19:+ 36306
# chr19_gl000208_random:+ 3
# chr19_gl000208_random:- 2
# chr19_gl000209_random:- 1
# chr19_gl000209_random:+ 2
# chr1:- 82202
# chr1:+ 85169
# chr1_gl000191_random:- 29
# chr1_gl000191_random:+ 4
# chr1_gl000192_random:- 31
# chr20:+ 18840
# chr20:- 16833
# chr21:- 11799
# chr21:+ 11750
# chr22:+ 15315
# chr22:- 13581
# chr2:- 63280
# chr2:+ 66128
# chr3:+ 46026
# chr3:- 46346
# chr4_ctg9_hap1:- 1
# chr4:+ 31481
# chr4:- 30473
# chr4_gl000193_random:- 25
# chr4_gl000193_random:+ 11
# chr4_gl000194_random:- 27
# chr4_gl000194_random:+ 4
# chr5:- 42051
# chr5:+ 48725
# chr6_apd_hap1:- 3
# chr6_cox_hap2:+ 81
# chr6_cox_hap2:- 19
# chr6_dbb_hap3:+ 10
# chr6_dbb_hap3:- 7
# chr6:+ 47698
# chr6:- 47104
# chr6_mann_hap4:- 49
# chr6_mann_hap4:+ 45
# chr6_mcf_hap5:+ 15
# chr6_mcf_hap5:- 43
# chr6_qbl_hap6:+ 55
# chr6_qbl_hap6:- 41
# chr6_ssto_hap7:- 16
# chr6_ssto_hap7:+ 4
# chr7:+ 46670
# chr7:- 42008
# chr7_gl000195_random:+ 52
# chr7_gl000195_random:- 143
# chr8:- 35076
# chr8:+ 29946
# chr8_gl000196_random:+ 4
# chr9:- 29468
# chr9:+ 28025
# chr9_gl000198_random:- 2
# chr9_gl000198_random:+ 9
# chr9_gl000199_random:- 2
# chr9_gl000199_random:+ 6
# chrM:+ 13007
# chrM:- 2119
# chrUn_gl000211:+ 3
# chrUn_gl000211:- 2
# chrUn_gl000212:+ 22
# chrUn_gl000212:- 2
# chrUn_gl000213:+ 1
# chrUn_gl000213:- 1
# chrUn_gl000214:- 22
# chrUn_gl000214:+ 12
# chrUn_gl000216:- 13
# chrUn_gl000216:+ 2
# chrUn_gl000217:- 2
# chrUn_gl000218:- 26
# chrUn_gl000218:+ 6
# chrUn_gl000219:- 9
# chrUn_gl000219:+ 10
# chrUn_gl000220:+ 433
# chrUn_gl000220:- 192
# chrUn_gl000221:- 6
# chrUn_gl000221:+ 9
# chrUn_gl000222:+ 4
# chrUn_gl000222:- 2
# chrUn_gl000224:+ 14
# chrUn_gl000224:- 25
# chrUn_gl000225:+ 10
# chrUn_gl000225:- 7
# chrUn_gl000227:+ 1
# chrUn_gl000229:- 4
# chrUn_gl000229:+ 6
# chrUn_gl000230:- 2
# chrUn_gl000230:+ 1
# chrUn_gl000231:+ 1
# chrUn_gl000232:+ 3
# chrUn_gl000232:- 5
# chrUn_gl000234:- 3
# chrUn_gl000234:+ 1
# chrUn_gl000235:+ 3
# chrUn_gl000235:- 1
# chrUn_gl000240:+ 1
# chrUn_gl000241:+ 7
# chrUn_gl000241:- 3
# chrUn_gl000242:+ 2
# chrUn_gl000243:- 2
# chrUn_gl000248:- 1
# chrUn_gl000249:- 3
# chrX:- 22523
# chrX:+ 22410
# chrY:- 555
# chrY:+ 415
# ==end== 6.9 s;
# Total PAS number i=2732224; PAS number who has enough support number j=1574173; Ratio j/i=58%

# %%
# step2: same chr and strand, sort, cluster by distance.
import time;

def getClusterFromPasDB(pasDB, distance=24):
    pasCluster={} #total cluster, save cluster
    i=0
    start=time.time();
    for chrStrand in pasDB: #chr1:+  : [ 1,2,3,100,...]
        #print("==begin==",chrStrand, round(time.time()-start,2),'seconds elapsed');
        #print(chrStrand) #chr10:-
        pasDB[chrStrand].sort();# order
        #
        pasCluster[chrStrand]=[];#accept rs after cluster  chr1:+  : [ [1,2,3],  [100,113,120], ]
        tmp=[];# current cluster pos. In the end, add whole cluster to the array.
        lastPos=-1;
        for pos in pasDB[chrStrand]:
            i+=1;
            if lastPos==-1: #when init
                tmp.append(pos); 
                lastPos=pos;
                continue;
            # if within <=distance, go on merge
            if pos-lastPos<=distance:
                tmp.append(pos); 
                lastPos=pos;
            else: # if > distance, then gave tmp to array cluster. Clean tmp for new commer next.
                pasCluster[chrStrand].append(tmp);
                tmp=[pos];
                lastPos=pos;
        if len(tmp)>0:#fix: the remaining of the chr is a cluster
            pasCluster[chrStrand].append(tmp);
    #
    timeString=time.strftime("%Y%m%d-%H%M%S", time.localtime());
    print("getClusterFromPasDB(): Total row number i=",i, '; distance=',distance,'; ',' consume time:',round(time.time()-start,2),'; ', timeString, sep='')
    #==end== Total row number i=1574173; distance=24; consume time0.84; 20190927-104513
    return pasCluster;
#
distance=24 #filter by distance
pasCluster1=getClusterFromPasDB(pasDB, distance)
#check()
# Out:
# getClusterFromPasDB(): Total row number i=1574173; distance=24;  consume time:0.74; 20210329-141521

# %%
# step3 [change some variables, so start from step2 if redo] 
# Parametr: distance Or distance/2, for long Cluster?

# For cluster span more than 24nt, get the Pos with most counts
# Check pasDict, based on Pos array and chrStrand, get the most reads, return the Pos
def getMaxPos(win, chrStrand):
    maxPos=win[0]
    maxCount=pasDict[chrStrand][str(maxPos)]
    #
    for pos in win:
        count=pasDict[chrStrand][str(pos)];
        #print(i, count)#133781868 804
        if count>maxCount:
            maxCount=count;
            maxPos=pos;
    #print(maxPos, maxCount)
    return maxPos
#test
#win=[133781863, 133781864, 133781865, 133781866, 133781867, 133781868, 133781869, 133781870, 133781884, 133781887, 133781888]
#getMaxPos(win,'chr10:-') #133781868


# keep pos within distance, others put back to pasDB2, and retun.(in order to the 2nd cluster)
def getPosFarFromMaxPos(pasCluster, distance):
    i=0
    j=0
    start=time.time()
    pasDB2={} #value is arr chr1:+ : [1,2,3] Sites whose distance to top counts too far

    for chrStrand in pasCluster:
        #chrStrand='chr10:-';
        pasDB2[chrStrand]=[]
        for index in range( len(pasCluster[chrStrand]) ):
            win=pasCluster[chrStrand][index]
            i+=1;
            #recluster span longer than 24nt
            if max(win)-min(win)>distance:
                inWin=[] #accept within, at last overwrite win
                maxPos=getMaxPos(win,chrStrand); # find the pos of maxCount, then find distance range
                for pos in win:
                    if maxPos-distance/2<=pos<=maxPos+distance/2: ##>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> critical
                        inWin.append(pos);
                    else:
                        pasDB2[chrStrand].append(pos); # if not in range, give back to DB, then recluster
                #print('chr10:'+str( min(win) )+'-'+str(max(win)),   '\t',length,'nt', win )
                # chr10:320394-320426 	 32 nt [320394, 320395, 320396, 320397, 320398, 320399, 320400, 320401, 320402, 320403, 320404, 320405, 320406, 320407, 320410, 320411, 320412, 320414, 320422, 320423, 320426]
                # chr10:856724-856762 	 38 nt [856724, 856731, 856732, 856733, 856734, 856735, 856736, 856737, 856738, 856739, 856740, 856741, 856742, 856744, 856745, 856761, 856762]
                j+=1;
                pasCluster[chrStrand][index]=inWin; #win=inWin;
    #
    timeString=time.strftime("%Y%m%d-%H%M%S", time.localtime()) 
    print('getPosFarFromMaxPos():Total cluster number i=',i, '; Too long cluster number j=',j, '; Ratio j/i=', round(j/i*100,2),'% ','; Time consuming:',round(time.time()-start,2),'s; ',timeString, sep='')
    # i= 25600 ; j= 1001 ; j/i= 4 % 的区域，cluster 长度超过24nt
    #### i= 16237 ; j= 439 ; j/i= 2.7 % 【过滤掉<=1的位点】
    # i= 16400 ; j= 351 ; j/i= 2 % #distance=20
    # i= 17144 ; j= 176 ; j/i= 1 % #distance=10
    # i= 18510 ; j= 79 ; j/i= 0.43 % #distance=5
    #getPosFarFromMaxPos():Total cluster number i=708828; Too long cluster number j=21201; Ratio j/i=2.99% ; Time consuming:0.61s; 20210329-141636       
    return pasDB2;
#
pasDB2=getPosFarFromMaxPos(pasCluster1, distance)
# Out:
# getPosFarFromMaxPos():Total cluster number i=708828; Too long cluster number j=21201; Ratio j/i=2.99% ; Time consuming:0.61s; 20210329-141636

# %%
# step4 begin loop
# get the number of pos in the value array of current cluster.
# chr1:+ :[1,2,300, ...]
def getPosNumber(pasDB2):
    number=0
    for chrStrand in pasDB2:
        arr=pasDB2[chrStrand];
        number+=len(arr)
    #print(number)
    return number;
#
#print('pasDB: ',getPosNumber(pasDB) )
#print('pasDB2: ', getPosNumber(pasDB2))

roundNum=0
while True:
    number=getPosNumber(pasDB2);
    roundNum+=1;
    print('='*50, 'roundNum=',roundNum, '; number left ', number);
    if number==0:
        break;
    
    #back to step2, using pasDB2 recluster
    pasCluster2=getClusterFromPasDB(pasDB2, distance)
    
    #back to step3, keep sites widin distance nt of maxPos, others back to pasDB2.
    pasDB2=getPosFarFromMaxPos(pasCluster2, distance)
    
    # merge pasCluster2 to pasCluster1
    i=0
    for chrStrand in pasCluster2:
        for cluster in pasCluster2[chrStrand]:
            i+=1
            pasCluster1[chrStrand].append(cluster);
            #print(chrStrand,cluster)
    print(i, 'cluster combined to pasCluster1\n')
# Out:
# ================================================== roundNum= 1 ; number left  130002
# getClusterFromPasDB(): Total row number i=130002; distance=24;  consume time:0.07; 20210329-141946
# getPosFarFromMaxPos():Total cluster number i=26669; Too long cluster number j=3607; Ratio j/i=13.53% ; Time consuming:0.06s; 20210329-141946
# 26669 cluster combined to pasCluster1
#
# ================================================== roundNum= 2 ; number left  34483
# getClusterFromPasDB(): Total row number i=34483; distance=24;  consume time:0.01; 20210329-141946
# getPosFarFromMaxPos():Total cluster number i=4477; Too long cluster number j=919; Ratio j/i=20.53% ; Time consuming:0.02s; 20210329-141946
# 4477 cluster combined to pasCluster1
#
# ================================================== roundNum= 3 ; number left  16983
# getClusterFromPasDB(): Total row number i=16983; distance=24;  consume time:0.0; 20210329-141946
# getPosFarFromMaxPos():Total cluster number i=1192; Too long cluster number j=306; Ratio j/i=25.67% ; Time consuming:0.01s; 20210329-141946
# 1192 cluster combined to pasCluster1
#
# ================================================== roundNum= 4 ; number left  11513
# getClusterFromPasDB(): Total row number i=11513; distance=24;  consume time:0.0; 20210329-141946
# getPosFarFromMaxPos():Total cluster number i=420; Too long cluster number j=148; Ratio j/i=35.24% ; Time consuming:0.01s; 20210329-141946
# 420 cluster combined to pasCluster1
#
# ================================================== roundNum= 5 ; number left  8672
# getClusterFromPasDB(): Total row number i=8672; distance=24;  consume time:0.0; 20210329-141946
# getPosFarFromMaxPos():Total cluster number i=218; Too long cluster number j=93; Ratio j/i=42.66% ; Time consuming:0.0s; 20210329-141946
# 218 cluster combined to pasCluster1
#
# ================================================== roundNum= 6 ; number left  6645
# getClusterFromPasDB(): Total row number i=6645; distance=24;  consume time:0.0; 20210329-141946
# getPosFarFromMaxPos():Total cluster number i=124; Too long cluster number j=69; Ratio j/i=55.65% ; Time consuming:0.0s; 20210329-141946
# 124 cluster combined to pasCluster1
#
# ================================================== roundNum= 7 ; number left  5029
# getClusterFromPasDB(): Total row number i=5029; distance=24;  consume time:0.0; 20210329-141946
# getPosFarFromMaxPos():Total cluster number i=99; Too long cluster number j=53; Ratio j/i=53.54% ; Time consuming:0.0s; 20210329-141946
# 99 cluster combined to pasCluster1
#
# ================================================== roundNum= 8 ; number left  3695
# getClusterFromPasDB(): Total row number i=3695; distance=24;  consume time:0.0; 20210329-141946
# getPosFarFromMaxPos():Total cluster number i=80; Too long cluster number j=38; Ratio j/i=47.5% ; Time consuming:0.0s; 20210329-141946
# 80 cluster combined to pasCluster1
#
# ================================================== roundNum= 9 ; number left  2546
# getClusterFromPasDB(): Total row number i=2546; distance=24;  consume time:0.0; 20210329-141946
# getPosFarFromMaxPos():Total cluster number i=52; Too long cluster number j=25; Ratio j/i=48.08% ; Time consuming:0.0s; 20210329-141946
# 52 cluster combined to pasCluster1
#
# ================================================== roundNum= 10 ; number left  1794
# getClusterFromPasDB(): Total row number i=1794; distance=24;  consume time:0.0; 20210329-141946
# getPosFarFromMaxPos():Total cluster number i=40; Too long cluster number j=21; Ratio j/i=52.5% ; Time consuming:0.0s; 20210329-141946
# 40 cluster combined to pasCluster1
#
# ================================================== roundNum= 11 ; number left  1202
# getClusterFromPasDB(): Total row number i=1202; distance=24;  consume time:0.0; 20210329-141946
# getPosFarFromMaxPos():Total cluster number i=32; Too long cluster number j=16; Ratio j/i=50.0% ; Time consuming:0.0s; 20210329-141946
# 32 cluster combined to pasCluster1
#
# ================================================== roundNum= 12 ; number left  744
# getClusterFromPasDB(): Total row number i=744; distance=24;  consume time:0.0; 20210329-141946
# getPosFarFromMaxPos():Total cluster number i=21; Too long cluster number j=13; Ratio j/i=61.9% ; Time consuming:0.0s; 20210329-141946
# 21 cluster combined to pasCluster1
#
# ================================================== roundNum= 13 ; number left  439
# getClusterFromPasDB(): Total row number i=439; distance=24;  consume time:0.0; 20210329-141946
# getPosFarFromMaxPos():Total cluster number i=20; Too long cluster number j=10; Ratio j/i=50.0% ; Time consuming:0.0s; 20210329-141946
# 20 cluster combined to pasCluster1
#
# ================================================== roundNum= 14 ; number left  185
# getClusterFromPasDB(): Total row number i=185; distance=24;  consume time:0.0; 20210329-141946
# getPosFarFromMaxPos():Total cluster number i=12; Too long cluster number j=2; Ratio j/i=16.67% ; Time consuming:0.0s; 20210329-141946
# 12 cluster combined to pasCluster1
#
# ================================================== roundNum= 15 ; number left  50
# getClusterFromPasDB(): Total row number i=50; distance=24;  consume time:0.0; 20210329-141946
# getPosFarFromMaxPos():Total cluster number i=4; Too long cluster number j=0; Ratio j/i=0.0% ; Time consuming:0.0s; 20210329-141946
# 4 cluster combined to pasCluster1
#
# ================================================== roundNum= 16 ; number left  0

# %%
# step5: check total number of clusters
w=0
for chrStrand in pasCluster1:
    i=0;
    for win in pasCluster1[chrStrand]:
        i+=1;
    print(chrStrand, i)
    w+=i;
print(w) #742288 clusters
# Out:
# chr10:- 16874
# chr10:+ 17420
# chr11:- 19065
# chr11:+ 20068
# chr11_gl000202_random:+ 1
# chr12:- 17174
# chr12:+ 17078
# chr13:+ 9583
# chr13:- 9295
# chr14:+ 11089
# chr14:- 10564
# chr15:+ 10955
# chr15:- 11018
# chr16:- 11243
# chr16:+ 11761
# chr17_ctg5_hap1:+ 22
# chr17_ctg5_hap1:- 21
# chr17:- 15063
# chr17:+ 14614
# chr17_gl000203_random:- 1
# chr17_gl000204_random:+ 3
# chr17_gl000204_random:- 1
# chr17_gl000205_random:- 7
# chr17_gl000205_random:+ 21
# chr18:+ 8034
# chr18:- 8039
# chr19:- 13823
# chr19:+ 15402
# chr19_gl000208_random:+ 3
# chr19_gl000208_random:- 2
# chr19_gl000209_random:- 1
# chr19_gl000209_random:+ 2
# chr1:- 36677
# chr1:+ 38341
# chr1_gl000191_random:- 12
# chr1_gl000191_random:+ 4
# chr1_gl000192_random:- 16
# chr20:+ 8557
# chr20:- 8041
# chr21:- 5360
# chr21:+ 5451
# chr22:+ 6815
# chr22:- 6175
# chr2:- 30592
# chr2:+ 31510
# chr3:+ 22760
# chr3:- 22918
# chr4_ctg9_hap1:- 1
# chr4:+ 16918
# chr4:- 16506
# chr4_gl000193_random:- 14
# chr4_gl000193_random:+ 9
# chr4_gl000194_random:- 21
# chr4_gl000194_random:+ 4
# chr5:- 20888
# chr5:+ 22630
# chr6_apd_hap1:- 2
# chr6_cox_hap2:+ 17
# chr6_cox_hap2:- 14
# chr6_dbb_hap3:+ 6
# chr6_dbb_hap3:- 7
# chr6:+ 22918
# chr6:- 22685
# chr6_mann_hap4:- 22
# chr6_mann_hap4:+ 16
# chr6_mcf_hap5:+ 11
# chr6_mcf_hap5:- 10
# chr6_qbl_hap6:+ 21
# chr6_qbl_hap6:- 19
# chr6_ssto_hap7:- 8
# chr6_ssto_hap7:+ 2
# chr7:+ 21745
# chr7:- 20673
# chr7_gl000195_random:+ 29
# chr7_gl000195_random:- 63
# chr8:- 16702
# chr8:+ 15268
# chr8_gl000196_random:+ 2
# chr9:- 14187
# chr9:+ 13936
# chr9_gl000198_random:- 2
# chr9_gl000198_random:+ 7
# chr9_gl000199_random:- 2
# chr9_gl000199_random:+ 5
# chrM:+ 832
# chrM:- 483
# chrUn_gl000211:+ 3
# chrUn_gl000211:- 2
# chrUn_gl000212:+ 11
# chrUn_gl000212:- 2
# chrUn_gl000213:+ 1
# chrUn_gl000213:- 1
# chrUn_gl000214:- 15
# chrUn_gl000214:+ 11
# chrUn_gl000216:- 13
# chrUn_gl000216:+ 2
# chrUn_gl000217:- 2
# chrUn_gl000218:- 21
# chrUn_gl000218:+ 5
# chrUn_gl000219:- 9
# chrUn_gl000219:+ 7
# chrUn_gl000220:+ 125
# chrUn_gl000220:- 113
# chrUn_gl000221:- 5
# chrUn_gl000221:+ 6
# chrUn_gl000222:+ 3
# chrUn_gl000222:- 2
# chrUn_gl000224:+ 9
# chrUn_gl000224:- 13
# chrUn_gl000225:+ 8
# chrUn_gl000225:- 5
# chrUn_gl000227:+ 1
# chrUn_gl000229:- 4
# chrUn_gl000229:+ 5
# chrUn_gl000230:- 2
# chrUn_gl000230:+ 1
# chrUn_gl000231:+ 1
# chrUn_gl000232:+ 3
# chrUn_gl000232:- 4
# chrUn_gl000234:- 2
# chrUn_gl000234:+ 1
# chrUn_gl000235:+ 3
# chrUn_gl000235:- 1
# chrUn_gl000240:+ 1
# chrUn_gl000241:+ 7
# chrUn_gl000241:- 3
# chrUn_gl000242:+ 1
# chrUn_gl000243:- 1
# chrUn_gl000248:- 1
# chrUn_gl000249:- 2
# chrX:- 11605
# chrX:+ 11388
# chrY:- 354
# chrY:+ 342
# 742288

# %%
# Options: check
# check how many site in the cluster
#chr1:+  : [ [1,2], [300,314],... ]
def getPosNumberFrom(pasCluster1):
    i=0
    for chrStrand in pasCluster1:
        for c in pasCluster1[chrStrand]:
            if len(c)==0:
                print('0')
            i+=len(c)
    return i;
    #print(i)
print( 'pasCluster1:', getPosNumberFrom(pasCluster1) ) #1569257

def check():
    n1=getPosNumber(pasDB2);
    n2=getPosNumberFrom(pasCluster1);
    print('>'*70,"pasDB2:%d, pasCluster1:%d; Total:%d" %(n1, n2, n1+n2))
check()
# Out:
# pasCluster1: 1574173
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> pasDB2:0, pasCluster1:1574173; Total:1574173

# %%
# step2.5 check result
# print() cluster result, who span over 24 nt
def getLongClusterNumber(pasCluster):
    i=0
    j=0
    pasDB2={} #value like   arr chr1:+ : [1,2,3]
    tmpDB={};

    for chrStrand in pasCluster:
        #chrStrand='chr10:-';
        tmpDB[chrStrand]=[];
        for win in pasCluster[chrStrand]:
            i+=1;
            length=max(win)-min(win);
            if length>24:
                if j<5: #print some examples
                    print('chr10:'+str( min(win) )+'-'+str(max(win)),   '\t',length,'nt', win )
                # chr10:320394-320426 	 32 nt [320394, 320395, 320396, 320397, 320398, 320399, 320400, 320401, 320402, 320403, 320404, 320405, 320406, 320407, 320410, 320411, 320412, 320414, 320422, 320423, 320426]
                # chr10:856724-856762 	 38 nt [856724, 856731, 856732, 856733, 856734, 856735, 856736, 856737, 856738, 856739, 856740, 856741, 856742, 856744, 856745, 856761, 856762]
                j+=1;
    #
    print('cluster total number i=',i, '; cluster which longer than ',distance,'nt j=',j, '; Long/total cluster ratio j/i=', round(j/i*100,2),'%', sep='')
    # i= 25600 ; j= 1001 ; j/i= 4 % region, cluster span > 24nt
    # i= 16237 ; j= 439 ; j/i= 2.7 % filtr out  site <=1
    # i= 16400 ; j= 351 ; j/i= 2 % #distance=20
    # i= 17144 ; j= 176 ; j/i= 1 % #distance=10
    # i= 18510 ; j= 79 ; j/i= 0.43 % #distance=5
    return j;
#
getLongClusterNumber(pasCluster1)
# Out:
# cluster total number i=742288; cluster which longer than 24nt j=0; Long/total cluster ratio j/i=0.0%
# 0

# %%
# step6: get pos with most Counts within each cluster, save to another array: pasPostions  
# key is chr1:+ ， value is a dit {1:[1,24],  121:[100,121],  300:[300], ...} top count's pos:[arr of all pos in the cluster]
## for debug
def print2(*args):
    if printFlag==False: #False output nothing, True normal
        return;
    print(args)
#test
printFlag=False;

start=time.time();
pasPostions={}
i=0
for chrStrand in pasCluster1:
    pasPostions[chrStrand]={};
    for cluster in pasCluster1[chrStrand]:
        #print2(chrStrand, '='*80, cluster);###debug
        i+=1;            
        maxPos=cluster[0];
        maxCount=pasDict[chrStrand][str(maxPos)]; # count of this site
        #print2(maxPos, maxCount)
        for index in range(1,len(cluster)): # if only one site in the cluster, not enter for loop
            pos=cluster[index];
            count=pasDict[chrStrand][str(pos)]; #count
            #print2(pos, count) #debug
            if count>maxCount:
                maxPos=pos;
                maxCount=count;
                #print2("-"*10,'>current maxPos=', maxPos) #debug
        #
        print2(">"*20,'maxPos=', maxPos)
        pasPostions[chrStrand][maxPos]=cluster;# pos of maxCount as key, value is all the pos in the cluster
    #print(chrStrand, i)
print(i,' clusters; Time consuming:', round(time.time()-start,2),'s' , sep='') #742288 clusters
# Out:
# 742288 clusters; Time consuming:1.17s

# %%
# step7 save the array pasPostions to file
import json

print(os.getcwd()) #/data/jinwf/wangjl/apa/190705PAS/pdf

#json to file
with open("/data/jinwf/wangjl/apa/190705PAS/bed/pasPostions_siteAndIncludes_PY.json","w") as f:
    json.dump(pasPostions,f)
    print("Save to file: done")
# 26M Sep 27 17:03 pasPostions_siteAndIncludes_PY.json
# less pasPostions_siteAndIncludes_PY.json
#
# Out:
# /data/jinwf/wangjl/apa/190705PAS/pdf
# Save to file: done

# %%
# step8 output pasPostions to bed format, to compare with polyA_DB3
# chr10	159177	159177	chr10:159177:-	20	-

import re,time
fw=open("/data/jinwf/wangjl/apa/190705PAS/bed/pasPostions_siteAndIncludes_PY.bed","w")

start=time.time();
i=0
flag=True;
for chrStrand in pasPostions:
    #pasPostions str
    chrN,strand=re.split(':', chrStrand);
    # key is chr1:+ ， value is a dict {1:[1,24],  121:[100,121],  300:[300], ...} 
    # Pos of maxCount:[ all the pos in the cluster]
    for site in pasPostions[chrStrand]:
        i+=1;
        cluster=pasPostions[chrStrand][site];
        count=0;
        for pos in cluster:
            count+=pasDict[chrStrand][str(pos)];
        # to bed format
        site=str(site)
        arr=[chrN, site, site, chrN+":"+site+":"+strand, str(count), strand];
        fw.write('\t'.join(arr)+'\n');
    #print(chrStrand, i)
print(i,' clusters; Time consuming:', round(time.time()-start,2),'s' , sep='') #742288 clusters
fw.close()

# 35M Sep 27 17:33 pasPostions_siteAndIncludes_PY.bed
# $ head pasPostions_siteAndIncludes_PY.bed
#chr10	157706	157706	chr10:157706:-	5	-
#chr10	159177	159177	chr10:159177:-	20	-
#chr10	167933	167933	chr10:167933:-	3	-
#chr10	174098	174098	chr10:174098:-	142	-
#chr10	185668	185668	chr10:185668:-	13	-

# 742288clusters; Time consuming:1.75s
# Out:
# 742288 clusters; Time consuming:1.7s
